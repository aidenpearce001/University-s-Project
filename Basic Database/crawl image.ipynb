# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
import urllib.request

# %%
df = pd.read_csv("data/restaurant_info.csv")

# %%
hostname = "https://www.foody.vn"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0'}

dict1 = {}
for i,v in enumerate(df["Url"]):
    print(i)
    page = requests.get(hostname+v,headers=headers).text
    soup = BeautifulSoup(page)
    print(hostname+v)
    for k in soup.findAll("img", {"class": "pic-place"}):
        print(k['src'])
        dict1[df['Name'][i]] = "static/images/"+k['src'].split("/")[-1]
        
#         print(k['src'])
#         urllib.request.urlretrieve(k['src'], "data/images/"+k['src'].split("/")[-1])
# Out:
# 0
# https://www.foody.vn/ha-noi/banh-tom-ho-tay
# https://images.foody.vn/res/g1/27/prof/s576x330/foody-mobile-hmb-f-jpg-158-635779248871052800.jpg
# 1
# https://www.foody.vn/ha-noi/van-tue
# https://images.foody.vn/res/g1/33/prof/s576x330/foody-mobile-ha-jpg-478-635780213616839286.jpg
# 2
# https://www.foody.vn/ha-noi/ga-36-linh-dam
# https://images.foody.vn/res/g1/52/prof/s576x330/foody-upload-api-foody-mobile-ga-36-jpg-181218163309.jpg
# 3
# https://www.foody.vn/ha-noi/wabi-sabi
# https://images.foody.vn/res/g1/75/prof/s576x330/file_restaurant_photo_s9zg_16052-9d401050-201113165051.jpg
# 4
# https://www.foody.vn/ha-noi/miwa
# https://images.foody.vn/res/g1/77/prof/s576x330/foody-mobile-miwa1-jpg-193-635925107348761804.jpg
# 5
# https://www.foody.vn/ha-noi/vuon-am-thuc-ran-rao
# https://images.foody.vn/res/g1/89/prof/s576x330/foody-mobile-vuon-am-thuc-ran-rao.jpg
# 6
# https://www.foody.vn/ha-noi/snowz-the-japanese
# ...

# %%
dict1
# Out:
# {'Bánh Tôm Hồ Tây': 'static/images/foody-mobile-hmb-f-jpg-158-635779248871052800.jpg',
#  'Vạn Tuế - Nhà Hàng Tiệc Cưới': 'static/images/foody-mobile-ha-jpg-478-635780213616839286.jpg',
#  'Gà 36 - Linh Đàm': 'static/images/foody-upload-api-foody-mobile-ga-36-jpg-181218163309.jpg',
#  'Wabi Sabi - Lẩu Nhật Bản': 'static/images/file_restaurant_photo_s9zg_16052-9d401050-201113165051.jpg',
#  'Miwa - Ẩm thực Nhật': 'static/images/foody-mobile-miwa1-jpg-193-635925107348761804.jpg',
#  'Vườn Ẩm Thực Rắn Ráo': 'static/images/foody-mobile-vuon-am-thuc-ran-rao.jpg',
#  'Snowz The Japanese - Buffet': 'static/images/foody-mobile-snow-jpg-786-635900104672366396.jpg',
#  'Đèn Lồng Đỏ - Ẩm Thực Trung Hoa': 'static/images/foody-mobile-den-long-do.jpg',
#  'Phố Biển - Tràng Thi': 'static/images/foody-mobile-pho-bien-trang-thi.jpg',
#  'Buffet Việt - Tăng Bạt Hổ': 'static/images/foody-mobile-bfv-jpg-363-635781866862347059.jpg',
# ...

# %%
#Dict to file
with open('images_map','w+',encoding='utf-8') as f:
    for k,v in dict1.items():
        f.write(k+":"+v+'\n')

# %%
#file to dict
dictionary = {}
with open('images_map','r',encoding='utf-8') as fd:
    for i in fd:
        dictionary[i.split(":")[0]] = i.split(":")[-1].rstrip()

# %%
dictionary['Vạn Tuế - Nhà Hàng Tiệc Cưới']
# Out:
# 'static/images/foody-mobile-ha-jpg-478-635780213616839286.jpg'

# %%
dictionary
# Out:
# {'Bánh Tôm Hồ Tây': 'static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg',
#  'Vạn Tuế - Nhà Hàng Tiệc Cưới': 'static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg',
#  'Gà 36 - Linh Đàm': 'static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg',
#  'Wabi Sabi - Lẩu Nhật Bản': 'static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg',
#  'Miwa - Ẩm thực Nhật': 'static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg',
#  'Vườn Ẩm Thực Rắn Ráo': 'static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg',
#  'Snowz The Japanese - Buffet': 'static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg',
#  'Đèn Lồng Đỏ - Ẩm Thực Trung Hoa': 'static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg',
#  'Phố Biển - Tràng Thi': 'static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg',
# ...

# %%
f1 = open('new','w+',encoding='utf-8')
with open('images_map','r+',encoding='utf-8') as f:
    for i in f:
        print(i.split(":")[-1].rstrip().replace("data/","static/"))
        f1.write(i.split(":")[0] +":"+i.split(":")[-1].rstrip().replace("data/","static/")+'\n')
#     dictionary[i.split(":")[0]] = i.split(":")[-1].rstrip()
f1.close()
# Out:
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# static/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg
# ...

# %%
dictionary['Bánh Tôm Hồ Tây']
# Out:
# 'data/images/foody-upload-api-foody-mobile-unnamed-1-200602103215.jpg'

# %%
url = "https://www.foody.vn/ha-noi/banh-tom-ho-tay"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0'}
page = requests.get(url,headers=headers).text
page
soup = BeautifulSoup(page)

# %%
for i in soup.findAll("img", {"class": "pic-place"}):
    print(i['src'].split("/")[-1])
# Out:
# foody-mobile-hmb-f-jpg-158-635779248871052800.jpg

# %%
import urllib.request

urllib.request.urlretrieve("https://images.foody.vn/res/g1/27/prof/s576x330/foody-mobile-hmb-f-jpg-158-635779248871052800.jpg", "local-filename.jpg")
# Out:
# ('local-filename.jpg', <http.client.HTTPMessage at 0x2dcd1e37f28>)

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0','Host': 'www.foody.vn','Referer': 'https://www.foody.vn/ha-noi'}
page = requests.get("https://www.foody.vn/ha-noi",headers=headers).text
soup = BeautifulSoup(page)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Địa điểm ăn uống, ẩm thực, ăn gì ở đâu tại Hà Nội, nhà hàng, cafe | Ăn uống | Foody.vn</title>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
# <meta content="Địa điểm ăn uống, ẩm thực tại Hà Nội - Nơi chia sẻ và đánh giá địa điểm, với hàng ngàn địa điểm về ẩm thực, giải trí cùng hàng ngàn bình luận. Tham gia để chia sẻ trải nghiệm với cộng đồng" name="description"/>
# <meta content="Địa điểm ăn uống, ẩm thực, nhà hàng, cafe, bar/pub, quán ăn" name="keywords"/>
# <meta content="app-id=1218739449" name="apple-itunes-app"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="9F288B3B53D32225CE6A70FA2DB2BF6D" name="msvalidate.01"/>
# <link href="/favicon.ico" rel="SHORTCUT ICON"/>
# ...
